# %% [markdown]
# # Artificial Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/krishnaik06/Complete-Deep-Learning/master/ANN/Churn_Modelling.csv")

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
X = data.iloc[:,3:13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y = data.iloc[:,13]
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
geography = pd.get_dummies(X["Geography"],drop_first=True)
geography
# Out:
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 2 columns]

# %%
gender=pd.get_dummies(X['Gender'],drop_first=True)
gender
# Out:
#        Male
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9995   True
# 9996   True
# 9997  False
# 9998   True
# 9999  False
#
# [10000 rows x 1 columns]

# %%
X = pd.concat([X,geography,gender],axis=1)
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0             1               1        101348.88    False  False  False
# 1             0               1        112542.58    False   True  False
# 2             1               0        113931.57    False  False  False
# 3             0               0         93826.63    False  False  False
# 4             1               1         79084.10    False   True  False
# ...         ...             ...              ...      ...    ...    ...
# 9995          1               0         96270.64    False  False   True
# 9996          1               1        101699.77    False  False   True
# 9997          0               1         42085.58    False  False  False
# 9998          1               0         92888.52     True  False   True
# 9999          1               0         38190.78    False  False  False
#
# [10000 rows x 13 columns]

# %%
X = X.drop(['Geography','Gender'],axis=1)
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0                  1        101348.88    False  False  False
# 1                  1        112542.58    False   True  False
# 2                  0        113931.57    False  False  False
# 3                  0         93826.63    False  False  False
# 4                  1         79084.10    False   True  False
# ...              ...              ...      ...    ...    ...
# 9995               0         96270.64    False  False   True
# 9996               1        101699.77    False  False   True
# 9997               1         42085.58    False  False  False
# 9998               0         92888.52     True  False   True
# 9999               0         38190.78    False  False  False
#
# [10000 rows x 11 columns]

# %% [markdown]
# # Splitting the dataset into the training and test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7389          667   34       5       0.00              2          1
# 9275          427   42       1   75681.52              1          1
# 2995          535   29       2  112367.34              1          1
# 5316          654   40       5  105683.63              1          1
# 356           850   57       8  126776.30              2          1
# ...           ...  ...     ...        ...            ...        ...
# 9225          594   32       4  120074.97              2          1
# 4859          794   22       4  114440.24              1          1
# 3264          738   35       5  161274.05              2          1
# 9845          590   38       9       0.00              2          1
# 2732          623   48       1  108076.33              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 7389               0        163830.64    False   True  False
# 9275               1         57098.00     True  False   True
# 2995               0        185630.76    False  False  False
# 5316               0        173617.09    False   True   True
# 356                1        132298.49    False   True  False
# ...              ...              ...      ...    ...    ...
# 9225               1        162961.79     True  False  False
# 4859               1        107753.07    False   True  False
# 3264               0        181429.87    False  False   True
# 9845               1        148750.16    False   True  False
# 2732               0        118855.26     True  False  False
#
# [8000 rows x 11 columns]

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
# Out:
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
X_test = sc.transform(X_test)
# Out:
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  1.75486502,
#         -0.57369368, -1.09168714],
#        [-1.31490297,  0.10961719, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        [ 0.57162971,  0.30102557,  1.04473698, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ..., -0.5698444 ,
#          1.74309049,  0.91601335],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  1.75486502,
#         -0.57369368,  0.91601335]])

# %% [markdown]
# # Now let's make the ANN

# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
classifier = Sequential()

# %%
classifier

# %%
classifier.add(Dense(units=6,kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# %%
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu'))

# %%
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history = classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs = 50)
# Out:
# Epoch 1/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3606 - accuracy: 0.8500 - val_loss: 0.3795 - val_accuracy: 0.8360
# Epoch 2/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3555 - accuracy: 0.8515 - val_loss: 0.3795 - val_accuracy: 0.8353
# Epoch 3/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3527 - accuracy: 0.8526 - val_loss: 0.3752 - val_accuracy: 0.8429
# Epoch 4/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3503 - accuracy: 0.8545 - val_loss: 0.3742 - val_accuracy: 0.8391
# Epoch 5/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3492 - accuracy: 0.8545 - val_loss: 0.3725 - val_accuracy: 0.8440
# Epoch 6/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3480 - accuracy: 0.8548 - val_loss: 0.3718 - val_accuracy: 0.8470
# Epoch 7/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3464 - accuracy: 0.8528 - val_loss: 0.3714 - val_accuracy: 0.8436
# Epoch 8/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3452 - accuracy: 0.8582 - val_loss: 0.3723 - val_accuracy: 0.8440
# Epoch 9/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3456 - accuracy: 0.8531 - val_loss: 0.3709 - val_accuracy: 0.8444
# Epoch 10/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3445 - accuracy: 0.8582 - val_loss: 0.3681 - val_accuracy: 0.8493
# Epoch 11/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3441 - accuracy: 0.8574 - val_loss: 0.3680 - val_accuracy: 0.8444
# Epoch 12/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3439 - accuracy: 0.8559 - val_loss: 0.3672 - val_accuracy: 0.8463
# Epoch 13/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3430 - accuracy: 0.8578 - val_loss: 0.3684 - val_accuracy: 0.8463
# Epoch 14/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3435 - accuracy: 0.8593 - val_loss: 0.3662 - val_accuracy: 0.8497
# Epoch 15/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3425 - accuracy: 0.8587 - val_loss: 0.3668 - val_accuracy: 0.8485
# Epoch 16/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3421 - accuracy: 0.8582 - val_loss: 0.3662 - val_accuracy: 0.8493
# Epoch 17/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3423 - accuracy: 0.8591 - val_loss: 0.3657 - val_accuracy: 0.8478
# Epoch 18/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3413 - accuracy: 0.8586 - val_loss: 0.3656 - val_accuracy: 0.8497
# Epoch 19/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3415 - accuracy: 0.8565 - val_loss: 0.3650 - val_accuracy: 0.8501
# Epoch 20/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3410 - accuracy: 0.8587 - val_loss: 0.3644 - val_accuracy: 0.8508
# Epoch 21/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3406 - accuracy: 0.8589 - val_loss: 0.3660 - val_accuracy: 0.8489
# Epoch 22/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3406 - accuracy: 0.8584 - val_loss: 0.3642 - val_accuracy: 0.8485
# Epoch 23/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3400 - accuracy: 0.8597 - val_loss: 0.3633 - val_accuracy: 0.8508
# Epoch 24/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3402 - accuracy: 0.8602 - val_loss: 0.3634 - val_accuracy: 0.8504
# Epoch 25/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3399 - accuracy: 0.8597 - val_loss: 0.3634 - val_accuracy: 0.8504
# Epoch 26/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3394 - accuracy: 0.8576 - val_loss: 0.3630 - val_accuracy: 0.8519
# Epoch 27/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3393 - accuracy: 0.8589 - val_loss: 0.3636 - val_accuracy: 0.8497
# Epoch 28/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3388 - accuracy: 0.8582 - val_loss: 0.3621 - val_accuracy: 0.8516
# Epoch 29/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3388 - accuracy: 0.8584 - val_loss: 0.3626 - val_accuracy: 0.8531
# Epoch 30/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3386 - accuracy: 0.8599 - val_loss: 0.3624 - val_accuracy: 0.8512
# Epoch 31/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3382 - accuracy: 0.8586 - val_loss: 0.3625 - val_accuracy: 0.8485
# Epoch 32/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3383 - accuracy: 0.8597 - val_loss: 0.3618 - val_accuracy: 0.8523
# Epoch 33/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3378 - accuracy: 0.8610 - val_loss: 0.3623 - val_accuracy: 0.8538
# Epoch 34/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3373 - accuracy: 0.8604 - val_loss: 0.3609 - val_accuracy: 0.8554
# Epoch 35/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3376 - accuracy: 0.8593 - val_loss: 0.3616 - val_accuracy: 0.8538
# Epoch 36/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3374 - accuracy: 0.8587 - val_loss: 0.3622 - val_accuracy: 0.8516
# Epoch 37/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3371 - accuracy: 0.8593 - val_loss: 0.3627 - val_accuracy: 0.8538
# Epoch 38/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3374 - accuracy: 0.8587 - val_loss: 0.3611 - val_accuracy: 0.8550
# Epoch 39/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3371 - accuracy: 0.8599 - val_loss: 0.3601 - val_accuracy: 0.8554
# Epoch 40/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3370 - accuracy: 0.8604 - val_loss: 0.3615 - val_accuracy: 0.8535
# Epoch 41/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3368 - accuracy: 0.8587 - val_loss: 0.3595 - val_accuracy: 0.8554
# Epoch 42/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3370 - accuracy: 0.8612 - val_loss: 0.3604 - val_accuracy: 0.8538
# Epoch 43/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3370 - accuracy: 0.8591 - val_loss: 0.3608 - val_accuracy: 0.8523
# Epoch 44/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3363 - accuracy: 0.8600 - val_loss: 0.3619 - val_accuracy: 0.8519
# Epoch 45/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3362 - accuracy: 0.8599 - val_loss: 0.3633 - val_accuracy: 0.8535
# Epoch 46/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3364 - accuracy: 0.8591 - val_loss: 0.3608 - val_accuracy: 0.8557
# Epoch 47/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3362 - accuracy: 0.8595 - val_loss: 0.3606 - val_accuracy: 0.8538
# Epoch 48/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3365 - accuracy: 0.8600 - val_loss: 0.3605 - val_accuracy: 0.8542
# Epoch 49/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3353 - accuracy: 0.8600 - val_loss: 0.3636 - val_accuracy: 0.8504
# Epoch 50/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3367 - accuracy: 0.8586 - val_loss: 0.3596 - val_accuracy: 0.8554

# %%
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Summarize history for accuracy

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1507,   88],
#        [ 199,  206]], dtype=int64)

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.8565
