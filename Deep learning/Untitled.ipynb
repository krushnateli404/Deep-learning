# %% [markdown]
# # Hyper Parameter Tuning

# %% [raw]
# # Keras Tuner-Decide number of hidden layers and neuron in neural network

# %%
# !pip install keras-tuner
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras-tuner
#   Obtaining dependency information for keras-tuner from https://files.pythonhosted.org/packages/b3/fb/35dab32ffc45faefcb6762088a1c105e421fbd253eb3e86002b70916e6f3/keras_tuner-1.4.4-py3-none-any.whl.metadata
#   Downloading keras_tuner-1.4.4-py3-none-any.whl.metadata (5.4 kB)
# Collecting keras-core (from keras-tuner)
#   Obtaining dependency information for keras-core from https://files.pythonhosted.org/packages/95/f7/b8dcff937ea64f822f0d3fe8c6010793406b82d14467cd0e9eecea458a40/keras_core-0.1.7-py3-none-any.whl.metadata
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: packaging in c:\users\krushna\appdata\roaming\python\python310\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in c:\users\krushna\appdata\roaming\python\python310\site-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: absl-py in c:\users\krushna\appdata\roaming\python\python310\site-packages (from keras-core->keras-tuner) (1.2.0)
# Requirement already satisfied: numpy in c:\users\krushna\appdata\roaming\python\python310\site-packages (from keras-core->keras-tuner) (1.23.3)
# Collecting rich (from keras-core->keras-tuner)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/be/2a/4e62ff633612f746f88618852a626bbe24226eba5e7ac90e91dcfd6a414e/rich-13.6.0-py3-none-any.whl.metadata
#   Downloading rich-13.6.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras-core->keras-tuner)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in c:\users\krushna\appdata\roaming\python\python310\site-packages (from keras-core->keras-tuner) (3.7.0)
# Collecting dm-tree (from keras-core->keras-tuner)
#   Downloading dm_tree-0.1.8-cp310-cp310-win_amd64.whl (101 kB)
#      ---------------------------------------- 101.3/101.3 kB ? eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\krushna\appdata\roaming\python\python310\site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krushna\appdata\roaming\python\python310\site-packages (from requests->keras-tuner) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krushna\appdata\roaming\python\python310\site-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krushna\appdata\roaming\python\python310\site-packages (from requests->keras-tuner) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krushna\appdata\roaming\python\python310\site-packages (from requests->keras-tuner) (2022.12.7)
# Collecting markdown-it-py>=2.2.0 (from rich->keras-core->keras-tuner)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\krushna\appdata\roaming\python\python310\site-packages (from rich->keras-core->keras-tuner) (2.13.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras-core->keras-tuner)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading keras_tuner-1.4.4-py3-none-any.whl (127 kB)
#    ---------------------------------------- 128.0/128.0 kB 7.4 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ---------------------------------------- 950.8/950.8 kB 8.6 MB/s eta 0:00:00
# Downloading rich-13.6.0-py3-none-any.whl (239 kB)
#    ---------------------------------------- 239.8/239.8 kB 7.4 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Installing collected packages: namex, kt-legacy, dm-tree, mdurl, markdown-it-py, rich, keras-core, keras-tuner
# Successfully installed dm-tree-0.1.8 keras-core-0.1.7 keras-tuner-1.4.4 kt-legacy-1.0.5 markdown-it-py-3.0.0 mdurl-0.1.2 namex-0.0.7 rich-13.6.0

# %%
import pandas as pd
from tensorflow.keras import layers
import keras_tuner
from keras_tuner import RandomSearch
from tensorflow.keras import Sequential
from tensorflow import keras

# %%
data = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/Keras-Tuner/main/Real_Combine.csv')
data
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 0      7.4   9.8   4.8  1017.6  93.0  0.5   4.3   9.4  219.720833
# 1      7.8  12.7   4.4  1018.5  87.0  0.6   4.4  11.1  182.187500
# 2      6.7  13.4   2.4  1019.4  82.0  0.6   4.8  11.1  154.037500
# 3      8.6  15.5   3.3  1018.7  72.0  0.8   8.1  20.6  223.208333
# 4     12.4  20.9   4.4  1017.3  61.0  1.3   8.7  22.2  200.645833
# ...    ...   ...   ...     ...   ...  ...   ...   ...         ...
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333
#
# [1093 rows x 9 columns]

# %%
data.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = data.iloc[:,:-1] #independant feature
y = data.iloc[:,-1]  #dependent feature

# %% [markdown]
# # HyperParameters

# %% [raw]
# 1. How many number of hidden layers we should have?
# 2. How many number of neurons we should have in hidden layers?
# 3. Learning Rate

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers',2,20)):
        model.add(layers.Dense(units=hp.Int('units_'+ str(i),
                                min_value=32,
                                max_value= 512,
                                step = 32),
                        activation='relu'))
    model.add(layers.Dense(1,activation='linear')) 
    model.compile(
              optimizer=keras.optimizers.Adam(
              hp.Choice('learning_rate',[1e-2,1e-3,1e-4])),
            loss = 'mean_absolute_error',
            metrics = ['mean_absolute_error'])
    return model

# %%
tuner = keras_tuner.RandomSearch(
    build_model,
    objective = 'val_mean_absolute_error',
    max_trials = 3,
    max_retries_per_trial = 3
    )
# Out:
# Reloading Tuner from .\untitled_project\tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 21
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_15 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_16 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_17 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_18 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=40)

# %%
X_train
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM
# 596   29.9  37.0  19.5  1008.3  39.0  2.7   4.4   9.4
# 316   29.0  34.8  24.6  1004.3  71.0  1.9   6.7  14.8
# 650   30.4  35.4  26.7   997.8  82.0  2.1   5.2  14.8
# 252   25.2  30.6  18.0  1008.2  71.0  2.6  10.0  20.6
# 532   19.3  28.0  13.0  1014.7  61.0  1.9   5.7  18.3
# ...    ...   ...   ...     ...   ...  ...   ...   ...
# 626   37.4  41.0  30.6   998.8  31.0  1.9  14.1  27.8
# 1016  34.1  37.2  29.0   998.4  61.0  2.6  11.5  22.2
# 165   18.2  28.1  10.4  1012.6  61.0  1.8   2.6  11.1
# 7     14.3  22.6   6.6  1016.3  76.0  0.8   0.4   3.5
# 219   19.8  27.1  12.8  1017.2  66.0  2.6   9.8  24.1
#
# [765 rows x 8 columns]

# %%
tuner.search(X_train,y_train,
            epochs=5,
            validation_data = (X_test,y_test))
# Out:
# Trial 3 Complete [00h 00m 04s]
# val_mean_absolute_error: nan
#
# Best val_mean_absolute_error So Far: nan
# Total elapsed time: 00h 00m 13s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 11                |19                |num_layers
# 448               |448               |units_0
# 32                |64                |units_1
# 0.01              |0.0001            |learning_rate
# 480               |32                |units_2
# 384               |32                |units_3
# 128               |32                |units_4
# 192               |32                |units_5
# 352               |32                |units_6
# 128               |32                |units_7
# 416               |32                |units_8
# 352               |32                |units_9
# 352               |32                |units_10
# 448               |32                |units_11
# 256               |32                |units_12
# 160               |32                |units_13
# 320               |32                |units_14
# 448               |32                |units_15
# 320               |32                |units_16
# 320               |32                |units_17
# 448               |32                |units_18
#
# Epoch 1/5
# 24/24 [==============================] - 2s 30ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 15ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 15ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 15ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 15ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\metrics_tracking.py:110: RuntimeWarning: All-NaN axis encountered
#   np.nanmin(values) if self.direction == "min" else np.nanmax(values)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 tuner.search(X_train,y_train,
#       2             epochs=5,
#       3             validation_data = (X_test,y_test))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\base_tuner.py:231, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     229     self.on_trial_begin(trial)
#     230     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 231     self.on_trial_end(trial)
#     232 self.on_search_end()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\base_tuner.py:335, in BaseTuner.on_trial_end(self, trial)
#     329 def on_trial_end(self, trial):
#     330     """Called at the end of a trial.
#     331
#     332     Args:
#     333         trial: A `Trial` instance.
#     334     """
# --> 335     self.oracle.end_trial(trial)
#     336     # Display needs the updated trial scored by the Oracle.
#     337     self._display.on_trial_end(self.oracle.get_trial(trial.trial_id))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:107, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     105     LOCKS[oracle].acquire()
#     106     THREADS[oracle] = thread_name
# --> 107 ret_val = func(*args, **kwargs)
#     108 if need_acquire:
#     109     THREADS[oracle] = None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:429, in Oracle.end_trial(self, trial)
#     427 if not self._retry(trial):
#     428     self.end_order.append(trial.trial_id)
# --> 429     self._check_consecutive_failures()
#     431 self._save_trial(trial)
#     432 self.save()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:386, in Oracle._check_consecutive_failures(self)
#     384     consecutive_failures = 0
#     385 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 386     raise RuntimeError(
#     387         "Number of consecutive failures exceeded the limit "
#     388         f"of {self.max_consecutive_failed_trials}.\n"
#     389         + (trial.message or "")
#     390     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='Air Quality Index')
# Out:
# Reloading Tuner from project\Air Quality Index\tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 18
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_15 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_data=(X_test, y_test))
# Out:
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 16                |16                |num_layers
# 192               |128               |units_0
# 416               |352               |units_1
# 0.0001            |0.0001            |learning_rate
# 160               |480               |units_2
# 384               |448               |units_3
# 128               |288               |units_4
# 224               |288               |units_5
# 128               |192               |units_6
# 128               |288               |units_7
# 448               |160               |units_8
# 352               |384               |units_9
# 288               |384               |units_10
# 384               |32                |units_11
# 192               |384               |units_12
# 192               |32                |units_13
# 128               |32                |units_14
# 256               |32                |units_15
#
# Epoch 1/5
# 24/24 [==============================] - 3s 35ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# 24/24 [==============================] - 3s 34ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 17ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 17ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 17ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 1/5
# 24/24 [==============================] - 3s 40ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\metrics_tracking.py:110: RuntimeWarning: All-NaN axis encountered
#   np.nanmin(values) if self.direction == "min" else np.nanmax(values)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 tuner.search(X_train, y_train,
#       2              epochs=5,
#       3              validation_data=(X_test, y_test))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\base_tuner.py:231, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     229     self.on_trial_begin(trial)
#     230     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 231     self.on_trial_end(trial)
#     232 self.on_search_end()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\base_tuner.py:335, in BaseTuner.on_trial_end(self, trial)
#     329 def on_trial_end(self, trial):
#     330     """Called at the end of a trial.
#     331
#     332     Args:
#     333         trial: A `Trial` instance.
#     334     """
# --> 335     self.oracle.end_trial(trial)
#     336     # Display needs the updated trial scored by the Oracle.
#     337     self._display.on_trial_end(self.oracle.get_trial(trial.trial_id))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:107, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     105     LOCKS[oracle].acquire()
#     106     THREADS[oracle] = thread_name
# --> 107 ret_val = func(*args, **kwargs)
#     108 if need_acquire:
#     109     THREADS[oracle] = None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:429, in Oracle.end_trial(self, trial)
#     427 if not self._retry(trial):
#     428     self.end_order.append(trial.trial_id)
# --> 429     self._check_consecutive_failures()
#     431 self._save_trial(trial)
#     432 self.save()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:386, in Oracle._check_consecutive_failures(self)
#     384     consecutive_failures = 0
#     385 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 386     raise RuntimeError(
#     387         "Number of consecutive failures exceeded the limit "
#     388         f"of {self.max_consecutive_failed_trials}.\n"
#     389         + (trial.message or "")
#     390     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(keras.layers.Dense(
      hp.Choice('units', [8, 16, 32]),
      activation='relu'))
    model.add(keras.layers.Dense(1, activation='relu'))
    model.compile(loss='mse')
    return model

# %%
tuner = keras_tuner.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=5)
# Out:
# Reloading Tuner from .\untitled_project\tuner0.json

# %%
tuner.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
best_model = tuner.get_best_models()[0]
# Out:
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 11                |17                |num_layers
# 448               |64                |units_0
# 32                |128               |units_1
# 0.01              |0.0001            |learning_rate
# 480               |32                |units_2
# 384               |192               |units_3
# 128               |288               |units_4
# 192               |96                |units_5
# 352               |320               |units_6
# 128               |160               |units_7
# 416               |256               |units_8
# 352               |320               |units_9
# 352               |224               |units_10
# 448               |480               |units_11
# 256               |256               |units_12
# 160               |160               |units_13
# 320               |384               |units_14
# 448               |480               |units_15
# 320               |96                |units_16
# 320               |480               |units_17
# 448               |160               |units_18
#
# Epoch 1/5
# 24/24 [==============================] - 2s 18ms/step - loss: nan - val_loss: nan
# Epoch 2/5
# 24/24 [==============================] - 0s 7ms/step - loss: nan - val_loss: nan
# Epoch 3/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - val_loss: nan
# Epoch 4/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - val_loss: nan
# Epoch 5/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - val_loss: nan
# C:\Users\KRUSHNA\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\metrics_tracking.py:110: RuntimeWarning: All-NaN axis encountered
#   np.nanmin(values) if self.direction == "min" else np.nanmax(values)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 tuner.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
#       2 best_model = tuner.get_best_models()[0]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\base_tuner.py:231, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     229     self.on_trial_begin(trial)
#     230     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 231     self.on_trial_end(trial)
#     232 self.on_search_end()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\base_tuner.py:335, in BaseTuner.on_trial_end(self, trial)
#     329 def on_trial_end(self, trial):
#     330     """Called at the end of a trial.
#     331
#     332     Args:
#     333         trial: A `Trial` instance.
#     334     """
# --> 335     self.oracle.end_trial(trial)
#     336     # Display needs the updated trial scored by the Oracle.
#     337     self._display.on_trial_end(self.oracle.get_trial(trial.trial_id))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:107, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     105     LOCKS[oracle].acquire()
#     106     THREADS[oracle] = thread_name
# --> 107 ret_val = func(*args, **kwargs)
#     108 if need_acquire:
#     109     THREADS[oracle] = None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:429, in Oracle.end_trial(self, trial)
#     427 if not self._retry(trial):
#     428     self.end_order.append(trial.trial_id)
# --> 429     self._check_consecutive_failures()
#     431 self._save_trial(trial)
#     432 self.save()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras_tuner\src\engine\oracle.py:386, in Oracle._check_consecutive_failures(self)
#     384     consecutive_failures = 0
#     385 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 386     raise RuntimeError(
#     387         "Number of consecutive failures exceeded the limit "
#     388         f"of {self.max_consecutive_failed_trials}.\n"
#     389         + (trial.message or "")
#     390     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in .\untitled_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 17
# units_0: 64
# units_1: 128
# learning_rate: 0.0001
# units_2: 32
# units_3: 192
# units_4: 288
# units_5: 96
# units_6: 320
# units_7: 160
# units_8: 256
# units_9: 320
# units_10: 224
# units_11: 480
# units_12: 256
# units_13: 160
# units_14: 384
# units_15: 480
# units_16: 96
# units_17: 480
# units_18: 160
# Score: nan
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 19
# units_0: 448
# units_1: 64
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# units_9: 32
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# units_14: 32
# units_15: 32
# units_16: 32
# units_17: 32
# units_18: 32
# Score: nan
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 11
# units_0: 448
# units_1: 32
# learning_rate: 0.01
# units_2: 480
# units_3: 384
# units_4: 128
# units_5: 192
# units_6: 352
# units_7: 128
# units_8: 416
# units_9: 352
# units_10: 352
# units_11: 448
# units_12: 256
# units_13: 160
# units_14: 320
# units_15: 448
# units_16: 320
# units_17: 320
# units_18: 448
# units: 8
# Score: nan
